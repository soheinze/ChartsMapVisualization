# %% [markdown]
# Note: Notebook has been last re-run on Dec 2, 2020.  Thus the results in this Notebook show inf

# %% [markdown]
# ### Setup

# %%
from my_credentials import my_client_id, my_client_secret

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd

import sys
import os
import re

import requests
from bs4 import BeautifulSoup

# %%
# Create a spotipy client
SPOTIPY_CLIENT_ID= my_client_id
SPOTIPY_CLIENT_SECRET= my_client_secret

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(SPOTIPY_CLIENT_ID,SPOTIPY_CLIENT_SECRET))

# %% [markdown]
# ### Get List of Playlists

# %%
# url = "https://open.spotify.com/genre/charts-regional"

# %%
file = 'Playlists.htm'
with open(file, 'r') as html_file:
    html = html_file.read()

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
#Extract all the Playlist hrefs
href_list = []

for tag in soup.find_all("a"):
    href_list.append(tag['href'])

# %% [markdown]
# ### Get Information about the playlists

# %%
# Playlist Names and IDs
playlists_infos = []

for href in href_list:
    info = []
    info.append(sp.playlist(href)['name'])
    info.append(sp.playlist(href)['id'])
    
    country = re.sub(" Top 50","",sp.playlist(href)['name'])
    info.append(country)
    
    playlists_infos.append(info)

# %%
playlists_infos[:5]
# Out:
# [['Global Top 50', '37i9dQZEVXbMDoHDwVN2tF', 'Global'],
#  ['Argentina Top 50', '37i9dQZEVXbMMy2roB9myp', 'Argentina'],
#  ['Australia Top 50', '37i9dQZEVXbJPcfkRz0wJ0', 'Australia'],
#  ['Belgium Top 50', '37i9dQZEVXbJNSeeHswcKB', 'Belgium'],
#  ['Bolivia Top 50', '37i9dQZEVXbJqfMFK4d691', 'Bolivia']]

# %%
playlists_df = pd.DataFrame(playlists_infos, columns =['Name', 'Playlist_Id', 'Country']) 
playlists_df
# Out:
#                      Name             Playlist_Id         Country
# 0           Global Top 50  37i9dQZEVXbMDoHDwVN2tF          Global
# 1        Argentina Top 50  37i9dQZEVXbMMy2roB9myp       Argentina
# 2        Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0       Australia
# 3          Belgium Top 50  37i9dQZEVXbJNSeeHswcKB         Belgium
# 4          Bolivia Top 50  37i9dQZEVXbJqfMFK4d691         Bolivia
# ..                    ...                     ...             ...
# 57         Hungary Top 50  37i9dQZEVXbNHwMxAkvmF8         Hungary
# 58         Uruguay Top 50  37i9dQZEVXbMJJi3wgRbAy         Uruguay
# 59  United Kingdom Top 50  37i9dQZEVXbLnolsZ8PSNw  United Kingdom
# 60   United States Top 50  37i9dQZEVXbLRQDuF5jeBp   United States
# 61         Vietnam Top 50  37i9dQZEVXbLdGSmz6xilI         Vietnam
#
# [62 rows x 3 columns]

# %% [markdown]
# ### Get the Tracklists per Playlist

# %%
tracklists_extended = []

for playlist in playlists_df['Playlist_Id']:
    tracklist = []
    
    playlist_id = '/playlist/'+playlist
    tracks_list = sp.playlist_tracks(playlist_id, fields='items(track(id,href,name,duration_ms))')['items']
    
    tracklist.append(tracks_list)
    tracklist.append(playlist)
    
    tracklists_extended.append(tracklist)

# %%
#tracklists_extended[61]

# %%
#Create a list where each element is one of the playlists
all_tracks_with_playlistid = []

for tracklist in tracklists_extended:
    for num,element in enumerate(tracklist[0]):
        temp_list = []
        #print(element, "\n")
        temp_list.append(element)
        temp_list.append(num+1)
        temp_list.append(tracklist[1])
        all_tracks_with_playlistid.append(temp_list)

# %%
for track in all_tracks_with_playlistid:
    track.append(track[0]['track']['id'])
    track.append(track[0]['track']['name'])

# %%
for track in all_tracks_with_playlistid:
    del track[0]  
    #print(track[0])
    #print(track[1])
    #print(track[2])
    #print(track[3])

# %%
tracks_df = pd.DataFrame(all_tracks_with_playlistid, columns=['Chartposition','Playlist_Id','Track_Id','Track_Name'])

# %%
tracks_df.head()
# Out:
#    Chartposition             Playlist_Id                Track_Id  \
# 0              1  37i9dQZEVXbMDoHDwVN2tF  4MzXwWMhyBbmu6hOcLVD49
# 1              2  37i9dQZEVXbMDoHDwVN2tF  0bYg9bo50gSsH3LtXe2SQn
# 2              3  37i9dQZEVXbMDoHDwVN2tF  35mvY5S1H3J2QZyna3TFe0
# 3              4  37i9dQZEVXbMDoHDwVN2tF  2XIc1pqjXV3Cr2BQUGNBck
# 4              5  37i9dQZEVXbMDoHDwVN2tF  2FRnf9qhLbvw8fu4IBXx78
#
#                         Track_Name
# 0                           DÁKITI
# 1  All I Want for Christmas Is You
# 2                        positions
# 3               LA NOCHE DE ANOCHE
# 4                   Last Christmas

# %% [markdown]
# ### Get Audio Feature Information

# %%
#sp.audio_features(track_id_list)

# %%
key_list = []

for trackid in tracks_df['Track_Id'][:1]:
    audiofeatures = sp.audio_features(trackid)
    
    
    key_list.append(audiofeatures[0].keys())
    
    #trackanalysis = [trackid, audiofeatures]
    #print(trackanalysis)

# %%
trackfeatureslist = []
for trackid in tracks_df['Track_Id']:
    audiofeatures = sp.audio_features(trackid)
    features = []
    features.append(trackid)
    for k,v in audiofeatures[0].items():
        features.append(v)    
    trackfeatureslist.append(features)
    #trackanalysis = [trackid, audiofeatures]
    #print(trackanalysis)

# %%
columnslist = ['Track_Id','danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','type','id','uri','track_href', 'analysis_url', 'duration_ms', 'time_signature']

# %%
trackfeatures_df = pd.DataFrame(trackfeatureslist, columns = columnslist)

# %%
trackfeatures_df
# Out:
#                     Track_Id  danceability  energy  key  loudness  mode  \
# 0     4MzXwWMhyBbmu6hOcLVD49         0.731   0.573    4   -10.059     0
# 1     0bYg9bo50gSsH3LtXe2SQn         0.336   0.627    7    -7.463     1
# 2     35mvY5S1H3J2QZyna3TFe0         0.737   0.802    0    -4.771     1
# 3     2XIc1pqjXV3Cr2BQUGNBck         0.856   0.618    7    -4.892     1
# 4     2FRnf9qhLbvw8fu4IBXx78         0.735   0.478    2   -12.472     1
# ...                      ...           ...     ...  ...       ...   ...
# 3095  79ME0P8ch9estARqe674HK         0.515   0.754   11    -3.773     1
# 3096  5Bti0azlFhMattVY76qFr9         0.617   0.212    0    -9.856     1
# 3097  2h1KRcol4TvqCl1Lf8RWio         0.777   0.729    1    -4.577     0
# 3098  0J2otOvMdg62gVMMjwOvSK         0.534   0.499    9   -10.601     0
# 3099  6pZI0hE72OTSbsG12p8Fx4         0.755   0.684    6    -5.712     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.0544       0.40100          0.000052    0.1130    0.145  109.928
# 1          0.0384       0.16400          0.000000    0.0708    0.350  150.273
# 2          0.0878       0.46800          0.000000    0.0931    0.682  144.015
# 3          0.2860       0.03030          0.000000    0.0866    0.391   81.993
# 4          0.0293       0.18900          0.000002    0.3550    0.947  107.682
# ...           ...           ...               ...       ...      ...      ...
# 3095       0.2940       0.28200          0.000000    0.1250    0.365  140.062
# 3096       0.0334       0.95800          0.001570    0.1310    0.219  126.579
# 3097       0.0495       0.37500          0.000000    0.3470    0.239  112.001
# 3098       0.0416       0.04160          0.000041    0.2870    0.227   91.954
# 3099       0.0603       0.00628          0.000036    0.0791    0.122   99.990
#
#                 type                      id  \
# 0     audio_features  4MzXwWMhyBbmu6hOcLVD49
# 1     audio_features  0bYg9bo50gSsH3LtXe2SQn
# 2     audio_features  35mvY5S1H3J2QZyna3TFe0
# 3     audio_features  2XIc1pqjXV3Cr2BQUGNBck
# 4     audio_features  2FRnf9qhLbvw8fu4IBXx78
# ...              ...                     ...
# 3095  audio_features  79ME0P8ch9estARqe674HK
# 3096  audio_features  5Bti0azlFhMattVY76qFr9
# 3097  audio_features  2h1KRcol4TvqCl1Lf8RWio
# 3098  audio_features  0J2otOvMdg62gVMMjwOvSK
# 3099  audio_features  6pZI0hE72OTSbsG12p8Fx4
#
#                                        uri  \
# 0     spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 1     spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 2     spotify:track:35mvY5S1H3J2QZyna3TFe0
# 3     spotify:track:2XIc1pqjXV3Cr2BQUGNBck
# 4     spotify:track:2FRnf9qhLbvw8fu4IBXx78
# ...                                    ...
# 3095  spotify:track:79ME0P8ch9estARqe674HK
# 3096  spotify:track:5Bti0azlFhMattVY76qFr9
# 3097  spotify:track:2h1KRcol4TvqCl1Lf8RWio
# 3098  spotify:track:0J2otOvMdg62gVMMjwOvSK
# 3099  spotify:track:6pZI0hE72OTSbsG12p8Fx4
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 1     https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 2     https://api.spotify.com/v1/tracks/35mvY5S1H3J2...
# 3     https://api.spotify.com/v1/tracks/2XIc1pqjXV3C...
# 4     https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# ...                                                 ...
# 3095  https://api.spotify.com/v1/tracks/79ME0P8ch9es...
# 3096  https://api.spotify.com/v1/tracks/5Bti0azlFhMa...
# 3097  https://api.spotify.com/v1/tracks/2h1KRcol4Tvq...
# 3098  https://api.spotify.com/v1/tracks/0J2otOvMdg62...
# 3099  https://api.spotify.com/v1/tracks/6pZI0hE72OTS...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4MzX...       205090
# 1     https://api.spotify.com/v1/audio-analysis/0bYg...       241107
# 2     https://api.spotify.com/v1/audio-analysis/35mv...       172325
# 3     https://api.spotify.com/v1/audio-analysis/2XIc...       203201
# 4     https://api.spotify.com/v1/audio-analysis/2FRn...       262960
# ...                                                 ...          ...
# 3095  https://api.spotify.com/v1/audio-analysis/79ME...       248571
# 3096  https://api.spotify.com/v1/audio-analysis/5Bti...       261616
# 3097  https://api.spotify.com/v1/audio-analysis/2h1K...       192857
# 3098  https://api.spotify.com/v1/audio-analysis/0J2o...       229589
# 3099  https://api.spotify.com/v1/audio-analysis/6pZI...       193485
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3095               4
# 3096               4
# 3097               4
# 3098               4
# 3099               4
#
# [3100 rows x 19 columns]

# %% [markdown]
# ## Merge all Dataframes

# %%
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3100 entries, 0 to 3099
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Chartposition  3100 non-null   int64
#  1   Playlist_Id    3100 non-null   object
#  2   Track_Id       3100 non-null   object
#  3   Track_Name     3100 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 97.0+ KB

# %%
trackfeatures_df.drop_duplicates(inplace=True)

# %%
trackfeatures_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1075 entries, 0 to 3099
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track_Id          1075 non-null   object
#  1   danceability      1075 non-null   float64
#  2   energy            1075 non-null   float64
#  3   key               1075 non-null   int64
#  4   loudness          1075 non-null   float64
#  5   mode              1075 non-null   int64
#  6   speechiness       1075 non-null   float64
#  7   acousticness      1075 non-null   float64
#  8   instrumentalness  1075 non-null   float64
#  9   liveness          1075 non-null   float64
#  10  valence           1075 non-null   float64
#  11  tempo             1075 non-null   float64
#  12  type              1075 non-null   object
#  13  id                1075 non-null   object
#  14  uri               1075 non-null   object
#  15  track_href        1075 non-null   object
#  16  analysis_url      1075 non-null   object
#  17  duration_ms       1075 non-null   int64
#  18  time_signature    1075 non-null   int64
# dtypes: float64(9), int64(4), object(6)
# memory usage: 168.0+ KB

# %%
tracks_all_info = tracks_df.merge(trackfeatures_df,'left', left_on='Track_Id', right_on='Track_Id')

# %%
tracks_all_info
# Out:
#       Chartposition             Playlist_Id                Track_Id  \
# 0                 1  37i9dQZEVXbMDoHDwVN2tF  4MzXwWMhyBbmu6hOcLVD49
# 1                 2  37i9dQZEVXbMDoHDwVN2tF  0bYg9bo50gSsH3LtXe2SQn
# 2                 3  37i9dQZEVXbMDoHDwVN2tF  35mvY5S1H3J2QZyna3TFe0
# 3                 4  37i9dQZEVXbMDoHDwVN2tF  2XIc1pqjXV3Cr2BQUGNBck
# 4                 5  37i9dQZEVXbMDoHDwVN2tF  2FRnf9qhLbvw8fu4IBXx78
# ...             ...                     ...                     ...
# 3095             46  37i9dQZEVXbLdGSmz6xilI  79ME0P8ch9estARqe674HK
# 3096             47  37i9dQZEVXbLdGSmz6xilI  5Bti0azlFhMattVY76qFr9
# 3097             48  37i9dQZEVXbLdGSmz6xilI  2h1KRcol4TvqCl1Lf8RWio
# 3098             49  37i9dQZEVXbLdGSmz6xilI  0J2otOvMdg62gVMMjwOvSK
# 3099             50  37i9dQZEVXbLdGSmz6xilI  6pZI0hE72OTSbsG12p8Fx4
#
#                                Track_Name  danceability  energy  key  \
# 0                                  DÁKITI         0.731   0.573    4
# 1         All I Want for Christmas Is You         0.336   0.627    7
# 2                               positions         0.737   0.802    0
# 3                      LA NOCHE DE ANOCHE         0.856   0.618    7
# 4                          Last Christmas         0.735   0.478    2
# ...                                   ...           ...     ...  ...
# 3095  Tiền Nhiều Để Làm Gì (feat. Gducky)         0.515   0.754   11
# 3096                              Lạ Lùng         0.617   0.212    0
# 3097     The Right Journey (feat. Gducky)         0.777   0.729    1
# 3098                        Hoa Hải Đường         0.534   0.499    9
# 3099      Chú Chó Trên Ô Tô (feat. Tlinh)         0.755   0.684    6
#
#       loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0      -10.059     0       0.0544  ...    0.1130    0.145  109.928
# 1       -7.463     1       0.0384  ...    0.0708    0.350  150.273
# 2       -4.771     1       0.0878  ...    0.0931    0.682  144.015
# 3       -4.892     1       0.2860  ...    0.0866    0.391   81.993
# 4      -12.472     1       0.0293  ...    0.3550    0.947  107.682
# ...        ...   ...          ...  ...       ...      ...      ...
# 3095    -3.773     1       0.2940  ...    0.1250    0.365  140.062
# 3096    -9.856     1       0.0334  ...    0.1310    0.219  126.579
# 3097    -4.577     0       0.0495  ...    0.3470    0.239  112.001
# 3098   -10.601     0       0.0416  ...    0.2870    0.227   91.954
# 3099    -5.712     0       0.0603  ...    0.0791    0.122   99.990
#
#                 type                      id  \
# 0     audio_features  4MzXwWMhyBbmu6hOcLVD49
# 1     audio_features  0bYg9bo50gSsH3LtXe2SQn
# 2     audio_features  35mvY5S1H3J2QZyna3TFe0
# 3     audio_features  2XIc1pqjXV3Cr2BQUGNBck
# 4     audio_features  2FRnf9qhLbvw8fu4IBXx78
# ...              ...                     ...
# 3095  audio_features  79ME0P8ch9estARqe674HK
# 3096  audio_features  5Bti0azlFhMattVY76qFr9
# 3097  audio_features  2h1KRcol4TvqCl1Lf8RWio
# 3098  audio_features  0J2otOvMdg62gVMMjwOvSK
# 3099  audio_features  6pZI0hE72OTSbsG12p8Fx4
#
#                                        uri  \
# 0     spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 1     spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 2     spotify:track:35mvY5S1H3J2QZyna3TFe0
# 3     spotify:track:2XIc1pqjXV3Cr2BQUGNBck
# 4     spotify:track:2FRnf9qhLbvw8fu4IBXx78
# ...                                    ...
# 3095  spotify:track:79ME0P8ch9estARqe674HK
# 3096  spotify:track:5Bti0azlFhMattVY76qFr9
# 3097  spotify:track:2h1KRcol4TvqCl1Lf8RWio
# 3098  spotify:track:0J2otOvMdg62gVMMjwOvSK
# 3099  spotify:track:6pZI0hE72OTSbsG12p8Fx4
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 1     https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 2     https://api.spotify.com/v1/tracks/35mvY5S1H3J2...
# 3     https://api.spotify.com/v1/tracks/2XIc1pqjXV3C...
# 4     https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# ...                                                 ...
# 3095  https://api.spotify.com/v1/tracks/79ME0P8ch9es...
# 3096  https://api.spotify.com/v1/tracks/5Bti0azlFhMa...
# 3097  https://api.spotify.com/v1/tracks/2h1KRcol4Tvq...
# 3098  https://api.spotify.com/v1/tracks/0J2otOvMdg62...
# 3099  https://api.spotify.com/v1/tracks/6pZI0hE72OTS...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4MzX...      205090
# 1     https://api.spotify.com/v1/audio-analysis/0bYg...      241107
# 2     https://api.spotify.com/v1/audio-analysis/35mv...      172325
# 3     https://api.spotify.com/v1/audio-analysis/2XIc...      203201
# 4     https://api.spotify.com/v1/audio-analysis/2FRn...      262960
# ...                                                 ...         ...
# 3095  https://api.spotify.com/v1/audio-analysis/79ME...      248571
# 3096  https://api.spotify.com/v1/audio-analysis/5Bti...      261616
# 3097  https://api.spotify.com/v1/audio-analysis/2h1K...      192857
# 3098  https://api.spotify.com/v1/audio-analysis/0J2o...      229589
# 3099  https://api.spotify.com/v1/audio-analysis/6pZI...      193485
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ...             ...
# 3095              4
# 3096              4
# 3097              4
# 3098              4
# 3099              4
#
# [3100 rows x 22 columns]

# %%
playlists_df.head()
# Out:
#                Name             Playlist_Id    Country
# 0     Global Top 50  37i9dQZEVXbMDoHDwVN2tF     Global
# 1  Argentina Top 50  37i9dQZEVXbMMy2roB9myp  Argentina
# 2  Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0  Australia
# 3    Belgium Top 50  37i9dQZEVXbJNSeeHswcKB    Belgium
# 4    Bolivia Top 50  37i9dQZEVXbJqfMFK4d691    Bolivia

# %%
chart_infos = tracks_all_info.merge(playlists_df,'left', left_on='Playlist_Id', right_on='Playlist_Id')

# %%
chart_infos
# Out:
#       Chartposition             Playlist_Id                Track_Id  \
# 0                 1  37i9dQZEVXbMDoHDwVN2tF  4MzXwWMhyBbmu6hOcLVD49
# 1                 2  37i9dQZEVXbMDoHDwVN2tF  0bYg9bo50gSsH3LtXe2SQn
# 2                 3  37i9dQZEVXbMDoHDwVN2tF  35mvY5S1H3J2QZyna3TFe0
# 3                 4  37i9dQZEVXbMDoHDwVN2tF  2XIc1pqjXV3Cr2BQUGNBck
# 4                 5  37i9dQZEVXbMDoHDwVN2tF  2FRnf9qhLbvw8fu4IBXx78
# ...             ...                     ...                     ...
# 3095             46  37i9dQZEVXbLdGSmz6xilI  79ME0P8ch9estARqe674HK
# 3096             47  37i9dQZEVXbLdGSmz6xilI  5Bti0azlFhMattVY76qFr9
# 3097             48  37i9dQZEVXbLdGSmz6xilI  2h1KRcol4TvqCl1Lf8RWio
# 3098             49  37i9dQZEVXbLdGSmz6xilI  0J2otOvMdg62gVMMjwOvSK
# 3099             50  37i9dQZEVXbLdGSmz6xilI  6pZI0hE72OTSbsG12p8Fx4
#
#                                Track_Name  danceability  energy  key  \
# 0                                  DÁKITI         0.731   0.573    4
# 1         All I Want for Christmas Is You         0.336   0.627    7
# 2                               positions         0.737   0.802    0
# 3                      LA NOCHE DE ANOCHE         0.856   0.618    7
# 4                          Last Christmas         0.735   0.478    2
# ...                                   ...           ...     ...  ...
# 3095  Tiền Nhiều Để Làm Gì (feat. Gducky)         0.515   0.754   11
# 3096                              Lạ Lùng         0.617   0.212    0
# 3097     The Right Journey (feat. Gducky)         0.777   0.729    1
# 3098                        Hoa Hải Đường         0.534   0.499    9
# 3099      Chú Chó Trên Ô Tô (feat. Tlinh)         0.755   0.684    6
#
#       loudness  mode  speechiness  ...    tempo            type  \
# 0      -10.059     0       0.0544  ...  109.928  audio_features
# 1       -7.463     1       0.0384  ...  150.273  audio_features
# 2       -4.771     1       0.0878  ...  144.015  audio_features
# 3       -4.892     1       0.2860  ...   81.993  audio_features
# 4      -12.472     1       0.0293  ...  107.682  audio_features
# ...        ...   ...          ...  ...      ...             ...
# 3095    -3.773     1       0.2940  ...  140.062  audio_features
# 3096    -9.856     1       0.0334  ...  126.579  audio_features
# 3097    -4.577     0       0.0495  ...  112.001  audio_features
# 3098   -10.601     0       0.0416  ...   91.954  audio_features
# 3099    -5.712     0       0.0603  ...   99.990  audio_features
#
#                           id                                   uri  \
# 0     4MzXwWMhyBbmu6hOcLVD49  spotify:track:4MzXwWMhyBbmu6hOcLVD49
# 1     0bYg9bo50gSsH3LtXe2SQn  spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 2     35mvY5S1H3J2QZyna3TFe0  spotify:track:35mvY5S1H3J2QZyna3TFe0
# 3     2XIc1pqjXV3Cr2BQUGNBck  spotify:track:2XIc1pqjXV3Cr2BQUGNBck
# 4     2FRnf9qhLbvw8fu4IBXx78  spotify:track:2FRnf9qhLbvw8fu4IBXx78
# ...                      ...                                   ...
# 3095  79ME0P8ch9estARqe674HK  spotify:track:79ME0P8ch9estARqe674HK
# 3096  5Bti0azlFhMattVY76qFr9  spotify:track:5Bti0azlFhMattVY76qFr9
# 3097  2h1KRcol4TvqCl1Lf8RWio  spotify:track:2h1KRcol4TvqCl1Lf8RWio
# 3098  0J2otOvMdg62gVMMjwOvSK  spotify:track:0J2otOvMdg62gVMMjwOvSK
# 3099  6pZI0hE72OTSbsG12p8Fx4  spotify:track:6pZI0hE72OTSbsG12p8Fx4
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4MzXwWMhyBbm...
# 1     https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 2     https://api.spotify.com/v1/tracks/35mvY5S1H3J2...
# 3     https://api.spotify.com/v1/tracks/2XIc1pqjXV3C...
# 4     https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# ...                                                 ...
# 3095  https://api.spotify.com/v1/tracks/79ME0P8ch9es...
# 3096  https://api.spotify.com/v1/tracks/5Bti0azlFhMa...
# 3097  https://api.spotify.com/v1/tracks/2h1KRcol4Tvq...
# 3098  https://api.spotify.com/v1/tracks/0J2otOvMdg62...
# 3099  https://api.spotify.com/v1/tracks/6pZI0hE72OTS...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4MzX...      205090
# 1     https://api.spotify.com/v1/audio-analysis/0bYg...      241107
# 2     https://api.spotify.com/v1/audio-analysis/35mv...      172325
# 3     https://api.spotify.com/v1/audio-analysis/2XIc...      203201
# 4     https://api.spotify.com/v1/audio-analysis/2FRn...      262960
# ...                                                 ...         ...
# 3095  https://api.spotify.com/v1/audio-analysis/79ME...      248571
# 3096  https://api.spotify.com/v1/audio-analysis/5Bti...      261616
# 3097  https://api.spotify.com/v1/audio-analysis/2h1K...      192857
# 3098  https://api.spotify.com/v1/audio-analysis/0J2o...      229589
# 3099  https://api.spotify.com/v1/audio-analysis/6pZI...      193485
#
#      time_signature            Name  Country
# 0                 4   Global Top 50   Global
# 1                 4   Global Top 50   Global
# 2                 4   Global Top 50   Global
# 3                 4   Global Top 50   Global
# 4                 4   Global Top 50   Global
# ...             ...             ...      ...
# 3095              4  Vietnam Top 50  Vietnam
# 3096              4  Vietnam Top 50  Vietnam
# 3097              4  Vietnam Top 50  Vietnam
# 3098              4  Vietnam Top 50  Vietnam
# 3099              4  Vietnam Top 50  Vietnam
#
# [3100 rows x 24 columns]

# %% [markdown]
# ## Dataframe to JSON Format as needed

# %%
tracks_all_info.to_json (r'tracks_all.json', orient='records')

# %%
playlists_df.to_json(r'playlists_meta.json',orient='records')

# %% [markdown]
# **File to use for visualisation that has all the information needed:**

# %%
chart_infos.to_json(r'chart_infos.json',orient='records')
